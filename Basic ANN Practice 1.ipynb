# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv('breast_cancer.csv')
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.isnull().sum()
# Out:
# id                         0
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# ...

# %%
df['diagnosis'].unique()
# Out:
# array(['M', 'B'], dtype=object)

# %%
x=df.drop(columns = ['id','diagnosis'])
y = df['diagnosis']

# %%
x.shape
# Out:
# (569, 30)

# %%
from sklearn.preprocessing import StandardScaler

ss= StandardScaler()
x_scaled = pd.DataFrame(ss.fit_transform(x),columns=x.columns)
y = df['diagnosis'].replace({'M':1,'B':0})

# %%
x
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
x_scaled
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0       1.097064     -2.073335        1.269934   0.984375         1.568466
# 1       1.829821     -0.353632        1.685955   1.908708        -0.826962
# 2       1.579888      0.456187        1.566503   1.558884         0.942210
# 3      -0.768909      0.253732       -0.592687  -0.764464         3.283553
# 4       1.750297     -1.151816        1.776573   1.826229         0.280372
# ..           ...           ...             ...        ...              ...
# 564     2.110995      0.721473        2.060786   2.343856         1.041842
# 565     1.704854      2.085134        1.615931   1.723842         0.102458
# 566     0.702284      2.045574        0.672676   0.577953        -0.840484
# 567     1.838341      2.336457        1.982524   1.735218         1.525767
# 568    -1.808401      1.221792       -1.814389  -1.347789        -3.112085
#
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x_scaled,y,test_size=0.2,random_state=10)

# %%
x_train.shape
# Out:
# (455, 30)

# %%
x_test.shape
# Out:
# (114, 30)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
nn = Sequential()
nn.add(Dense(units=16,activation='relu',input_dim=30)) # HL1
nn.add(Dense(units=8,activation='relu')) # HL2
nn.add(Dense(units=1,activation='sigmoid')) # Output Layer
nn.compile(optimizer='Adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
x_train.shape
# Out:
# (455, 30)

# %%
455/32
# Out:
# 14.21875

# %%
nn.fit(x_train,y_train,batch_size=32,epochs=100)
# Out:
# Epoch 1/100
# 15/15 [==============================] - 1s 2ms/step - loss: 0.8000 - accuracy: 0.6044
# Epoch 2/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.5343 - accuracy: 0.7956
# Epoch 3/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.3981 - accuracy: 0.8747
# Epoch 4/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.3219 - accuracy: 0.8989
# Epoch 5/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2726 - accuracy: 0.9187
# Epoch 6/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2384 - accuracy: 0.9253
# Epoch 7/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2114 - accuracy: 0.9275
# Epoch 8/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.1906 - accuracy: 0.9407
# Epoch 9/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.1735 - accuracy: 0.9429
# Epoch 10/100
# ...

# %%
nn.evaluate(x_test,y_test)
# Out:
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1148 - accuracy: 0.9825
# [0.11484609544277191, 0.9824561476707458]

# %% [markdown]
# ## ANN Tuning

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout
from tensorflow.keras import regularizers,optimizers

# %%
def train_test(dropout,lr,lamb):
    nn_classifier= Sequential()  # Creating the layout
    nn_classifier.add(Dense(units=16,activation='relu',input_dim=30)) # Creating hidden layers
    nn_classifier.add(Dropout(dropout))
    nn_classifier.add(Dense(units=8,activation='relu')) # Creating hidden layers
    nn_classifier.add(Dropout(dropout))
    nn_classifier.add(Dense(units=1,activation='sigmoid',kernel_regularizer=regularizers.l2(lamb))) # output layers
    nn_classifier.compile(optimizer='Adam',loss='binary_crossentropy',metrics=['accuracy'])
    nn_classifier.fit(x_train,y_train,batch_size=32,epochs=100,verbose=0)
    train_score=nn_classifier.evaluate(x_train,y_train)
    test_score=nn_classifier.evaluate(x_test,y_test)
    return train_score,test_score

# %%
train_test(0.1,0.1,0.1)
# Out:
# ...
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0775 - accuracy: 0.9766
# ([0.07469293475151062, 0.9874371886253357],
#  [0.07750459760427475, 0.9766082167625427])

# %%
train_test(0.1,0.1,1)
# Out:
# ...
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1058 - accuracy: 0.9766
# ([0.11127260327339172, 0.9824120402336121],
#  [0.10580126196146011, 0.9766082167625427])
